# %%
import networkx as nx

# %%
import seaborn as sns

# %%
G = nx.Graph()

G.add_edge("a", "b", weight=0.6)
G.add_edge("a", "c", weight=0.2)
G.add_edge("c", "d", weight=0.1)
G.add_edge("c", "e", weight=0.7)
G.add_edge("c", "f", weight=0.9)
G.add_edge("a", "d", weight=0.3)

elarge = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] > 0.5]
esmall = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] <= 0.5]

pos = nx.spring_layout(G)  # positions for all nodes

# nodes
nx.draw_networkx_nodes(G, pos, node_size=700)

# edges
nx.draw_networkx_edges(G, pos, edgelist=elarge, width=6)
nx.draw_networkx_edges(
    G, pos, edgelist=esmall, width=6, alpha=0.5, edge_color="b", style="dashed"
)

# labels
nx.draw_networkx_labels(G, pos, font_size=20, font_family="sans-serif")
# Out:
# {'a': Text(-0.15355180102081226, 0.48921244804540076, 'a'),
#  'b': Text(-0.17293658606147713, 1.0, 'b'),
#  'c': Text(0.17528615871053047, -0.3547124000036792, 'c'),
#  'd': Text(-0.5667667898530768, 0.1312742802974167, 'd'),
#  'e': Text(0.6477118962360527, -0.48742604319804356, 'e'),
#  'f': Text(0.07025712198878332, -0.7783482851410948, 'f')}
